# %%
import numpy as np
import argparse
import dlib
import cv2
import imutils
import matplotlib.pyplot as plt
from face_process import Face_affine
import os

# %%
openface = Face_affine('./data_true/IMG_3115.jpg')
reacts = openface.get_reacts()
shapes = openface.get_shapes(reacts)
image_drop,shape_drop = openface.get_shape_drop(openface.image,shapes[0],reacts[0])
image_rotating_scaling,rect_scale = openface.rotating_scaling(image_drop,shape_drop,reacts[0])
plt.imshow(image_rotating_scaling)

# %%
img = openface.drop_all_black(image_rotating_scaling)
plt.imshow(img)
# Out:
# 190 44
